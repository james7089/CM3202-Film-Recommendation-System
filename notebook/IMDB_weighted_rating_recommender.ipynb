# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ast import literal_eval
import warnings; warnings.simplefilter('ignore')

# %%
movies_df = pd.read_csv("TheMoviesDataset\movies_metadata.csv")

# %%
movies_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
#reformates genres from [{'id': 1, 'name': 'x'}, {'id': 2, 'name': 'y'}] to [x, y]
movies_df['genres'] = movies_df['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
movies_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# ...

# %% [markdown]
# IMDB's weighted rating formula

# %% [markdown]
# v = number of votes for the movie

# %% [markdown]
# m = minimum votes required (e.g. 95th percentile)

# %% [markdown]
# R = Average rating of a movie (scale: 1-10)

# %% [markdown]
# C = mean vote of all movies

# %% [markdown]
# Weighted Rating (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C

# %%
# this is V
vote_counts = movies_df[movies_df['vote_count'].notnull()]['vote_count'].astype('int')

# this is R
vote_averages = movies_df[movies_df['vote_average'].notnull()]['vote_average'].astype('int')

# this is C
C = vote_averages.mean()

# %%
m = vote_counts.quantile(0.95)

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
movies_df['wr'] = movies_df.apply(weighted_rating, axis=1)

# %%
movies_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# ...

# %%
#movies ordered by IMDB weighted rating
movies_by_wr = movies_df.sort_values(by='wr', ascending=False)

# %%
movies_by_wr.head(5)
# Out:
#        adult                              belongs_to_collection     budget  \
# 314    False                                                NaN   25000000
# 834    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 12481  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# 2843   False                                                NaN   63000000
# 292    False                                                NaN    8000000
#
#                                  genres  \
# 314                      [Drama, Crime]
# 834                      [Drama, Crime]
# 12481  [Drama, Action, Crime, Thriller]
# 2843                            [Drama]
# 292                   [Thriller, Crime]
#
#                                            homepage   id    imdb_id  \
# 314                                             NaN  278  tt0111161
# 834                    http://www.thegodfather.com/  238  tt0068646
# ...
